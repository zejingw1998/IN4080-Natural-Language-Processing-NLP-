# %% [markdown]
# # Exercise Set 1
# <h2> IN4080 - 2026 </h2>
#
# *You will probably not manage to work through all of this exercise set during the group session. Continue
# to work on it by yourself after the group session and return to the teacher in later group sessions if you
# have any questions.*
#
#
# This exercises requires the following packages:
# * Spacy
# * Numpy
# * Pandas
# * Matplotlib

# %% [markdown]
# ## Part 0: Set up a working environment on your PC
#
# Follow the installation instructions on the course web page to set up a working environment on your
# own computer.
# The following exercises should be solved interactively in Python. We recommend using a Jupyter
# Notebook, but you can also work in a standard interactive Python prompt.

# %% [markdown]
# ### Jupyter notebooks?
#   The Jupyter Notebook is an interactive computing environment.
#
#   Read about:
#   - [Notebook Basics](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Notebook%20Basics.html)
#   - [Running Code](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Running%20Code.html)

# %% [markdown]
# ## Part 1: Precpocessing Data with SpaCy
#
# We will work with the book *Peter Pan*, which is available as plain text on Project Gutenberg.

# %% [markdown]
# a) Download the Plain Text UTF-8 file from https://www.gutenberg.org/ebooks/16 and place it in your working
# directory. Rename the file if necessary. Open the file in a text editor. Are there any particularities in the document
# that you’ll need to watch out when processing?

# %% [markdown]
# The text contains many line breaks, chapter headings, a table of contents, and Project Gutenberg information. These may affect the preprocessing and sentence segmentation.

# %% [markdown]
# b) This is a Jupyter notebook which is organized into cells. There are essentially two types of cells: text (Markdown)
# cells and code cells. You can execute a code cell by clicking on the Play button or by pressing Ctrl+Enter.
# Create a code cell below, load in the Peter Pan text, and print the length of the text. What does this number tell you?
#
#
# <details>
#   <summary>Code Solution</summary>
#
# ```python
# with open(‘peterpan.txt’, ‘r’, encoding=’utf-8-sig’) as f:
#   text = f.read()
#   print(len(text))
# ```
# </details>

# %% [markdown]
# c) We would now like preprocess the raw text. The NLP pipeline from `SpaCy` does a lot of the heavy lifting for us.
# Run the text through the SpaCy pipeline and print out the number of sentences in the resulting `Doc` object.
# Does the number of sentences correspond to your expectations? Inspect the data.
#
# [SpaCy Usage Documentation](https://spacy.io/usage)

# %% [markdown]
# d) It turns out that the initial text contains a lot of line breaks that make the processing harder than
# necessary. Replace all line breaks in the raw text with a space.
#
# *Hint* use regular expressions and the `re` library.
#
# If you are not familiar with regular expressions, let your teachers know. We won’t need them now, but they
# can come quite handy for a lot of text processing tasks, so it’s worth investing some time in learning the basics…

# %% [markdown]
# e) Run the new text through the sentence tokenizer again. How do you judge the result? Have new errors been introduced?

# %%
with open("peter-pan.txt", "r", encoding="utf-8-sig") as f:
    text = f.read()

print(len(text))

#Problem 1a

import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp(text)

sentences = list(doc.sents)

print(len(sentences))

for sentence in sentences[:20]:
    print(repr(sentence.text))

#The text contains 274155 characters. This number represents the total number of characters in the text, including letters, spaces, punctuation and line breaks.


#SpaCy finds 2954 sentences. However, after inspecting the first sentences, we can see that many sentences contain line breaks and some chapter headings are not segmented correctly.

import re 

clean_text = re.sub(r'\n+', ' ', text)

print(clean_text[:1000])

clean_doc = nlp(clean_text)

clean_sentences = list(clean_doc.sents)

print(len(clean_sentences))


for sentence in clean_sentences[:20]:
    print(repr(sentence.text))
# Out:
# 274155
# 2954
# 'Peter Pan\n\n[PETER AND WENDY]\n\nby J. M. Barrie [James Matthew Barrie]\n\nA Millennium Fulcrum Edition produced in 1991 by Duncan Research.'
# 'Note\nthat while a copyright was initially claimed for the labor involved in\ndigitization, that copyright claim is not consistent with current\ncopyright requirements.'
# 'This text, which matches the 1911 original\npublication, is in the public domain in the US.\n\n\n'
# 'Contents\n\n Chapter I. PETER BREAKS THROUGH\n Chapter II.'
# 'THE SHADOW\n Chapter III.'
# 'COME AWAY, COME AWAY!\n Chapter IV.'
# 'THE FLIGHT\n Chapter V. THE ISLAND COME TRUE\n Chapter VI.'
# 'THE LITTLE HOUSE\n Chapter VII.'
# 'THE HOME UNDER THE GROUND\n Chapter VIII.'
# 'THE MERMAIDS’ LAGOON\n Chapter IX.'
# 'THE NEVER BIRD\n Chapter X. THE HAPPY HOME\n Chapter XI.'
# 'WENDY’S STORY\n Chapter XII.'
# 'THE CHILDREN ARE CARRIED OFF\n Chapter XIII.'
# 'DO YOU BELIEVE IN FAIRIES?\n '
# 'Chapter XIV.'
# 'THE PIRATE SHIP\n Chapter XV.'
# '“HOOK OR ME THIS TIME”\n Chapter XVI.'
# 'THE RETURN HOME\n Chapter XVII.'
# 'WHEN WENDY GREW UP\n\n\n\n\nChapter I.\nPETER BREAKS THROUGH\n\n\nAll children, except one, grow up.'
# 'They soon know that they will grow\nup, and the way Wendy knew was this.'
# Peter Pan [PETER AND WENDY] by J. M. Barrie [James Matthew Barrie] A Millennium Fulcrum Edition produced in 1991 by Duncan Research. Note that while a copyright was initially claimed for the labor involved in digitization, that copyright claim is not consistent with current copyright requirements. This text, which matches the 1911 original publication, is in the public domain in the US. Contents  Chapter I. PETER BREAKS THROUGH  Chapter II. THE SHADOW  Chapter III. COME AWAY, COME AWAY!  Chapter IV. THE FLIGHT  Chapter V. THE ISLAND COME TRUE  Chapter VI. THE LITTLE HOUSE  Chapter VII. THE HOME UNDER THE GROUND  Chapter VIII. THE MERMAIDS’ LAGOON  Chapter IX. THE NEVER BIRD  Chapter X. THE HAPPY HOME  Chapter XI. WENDY’S STORY  Chapter XII. THE CHILDREN ARE CARRIED OFF  Chapter XIII. DO YOU BELIEVE IN FAIRIES?  Chapter XIV. THE PIRATE SHIP  Chapter XV. “HOOK OR ME THIS TIME”  Chapter XVI. THE RETURN HOME  Chapter XVII. WHEN WENDY GREW UP Chapter I. PETER BREAKS THROUGH All children, ex
# 3302
# 'Peter Pan'
# '[PETER AND WENDY] by J. M. Barrie [James Matthew Barrie] A Millennium Fulcrum Edition produced in 1991 by Duncan Research.'
# 'Note that while a copyright was initially claimed for the labor involved in digitization, that copyright claim is not consistent with current copyright requirements.'
# 'This text, which matches the 1911 original publication, is in the public domain in the US.'
# 'Contents  Chapter I. PETER BREAKS THROUGH  Chapter II.'
# 'THE SHADOW  Chapter III.'
# 'COME AWAY, COME AWAY!  '
# 'Chapter IV.'
# 'THE FLIGHT  Chapter V. THE ISLAND COME TRUE  Chapter VI.'
# 'THE LITTLE HOUSE  Chapter VII.'
# 'THE HOME UNDER THE GROUND  Chapter VIII.'
# 'THE MERMAIDS’ LAGOON  Chapter IX.'
# 'THE NEVER BIRD  Chapter X. THE HAPPY HOME  Chapter XI.'
# 'WENDY’S STORY  Chapter XII.'
# 'THE CHILDREN ARE CARRIED OFF  Chapter XIII.'
# 'DO YOU BELIEVE IN FAIRIES?  '
# 'Chapter XIV.'
# 'THE PIRATE SHIP  Chapter XV.'
# '“HOOK OR ME THIS TIME”  Chapter XVI.'
# 'THE RETURN HOME  Chapter XVII.'

# %% [markdown]
# ## Part 2: Frequency distributions and Pandas
#
# In this exercise set, we want to study the frequency distributions of words in the text.
# Python provides a Counter class that counts repeated elements in a list and stores the counts as a
# dictionary. We can set up the counter, get the most common elements, and the count for a specific element as follows:
#
# ```python
# import collections
#
# c = collections.Counter(tokens)
# print(c.most_common(10))
# print(c['with'])
# ```

# %% [markdown]
# a) Print out the 10 most frequent tokens in the text.

# %%
with open("peter-pan.txt", "r", encoding="utf-8-sig") as f:
    text = f.read()

from collections import Counter

words = text.split()

counter_1 = Counter(words)

print(counter_1)


words = [token.text for token in clean_doc]

counter_1 = Counter(words)

print(counter_1)


print(counter_1.most_common(20))
# Out:
# Counter({'the': 2310, 'and': 1385, 'to': 1205, 'a': 956, 'of': 914, 'was': 899, 'he': 866, 'in': 679, 'that': 565, 'had': 497, 'it': 471, 'she': 465, 'they': 464, 'his': 455, 'you': 403, 'not': 382, 'for': 376, 'but': 376, 'her': 360, 'with': 356, 'is': 339, 'on': 323, 'at': 316, 'as': 312, 'I': 253, 'have': 248, 'be': 247, 'were': 243, 'Peter': 235, 'all': 220, 'said': 218, 'their': 213, 'would': 209, 'Wendy': 199, 'so': 197, 'this': 190, 'are': 186, 'him': 186, 'by': 179, 'one': 169, 'them': 165, 'He': 163, '“I': 159, 'when': 152, 'The': 146, 'from': 145, 'could': 139, 'we': 138, 'been': 135, 'who': 133, 'no': 133, 'or': 128, 'if': 125, 'which': 123, 'It': 121, 'did': 115, 'out': 115, 'up': 112, 'there': 111, 'She': 109, 'said,': 108, 'about': 106, 'what': 105, 'an': 102, 'They': 101, 'into': 100, 'do': 98, 'Darling': 93, 'little': 91, 'like': 86, 'will': 85, 'see': 85, 'only': 84, 'Hook': 84, 'time': 81, 'your': 80, 'Project': 77, 'John': 76, 'children': 75, 'now': 75, 'just': 73, 'Mrs.': 72, 'cried': 72, 'came': 71, 'other': 71, 'thought': 69, 'my': 69, 'must': 68, 'Michael': 68, 'then': 67, 'any': 67, 'him.': 66, 'know': 65, 'never': 65, 'But': 65, 'first': 64, 'very': 64, 'knew': 63, 'it,': 62, 'quite': 62, 'more': 62, 'boys': 61, 'way': 60, 'such': 60, 'than': 60, 'how': 60, 'over': 56, 'it.': 56, 'go': 56, 'course': 55, 'don’t': 54, 'Wendy,': 54, 'him,': 53, 'Gutenberg-tm': 53, 'still': 51, 'always': 50, 'come': 50, 'can': 50, 'down': 50, 'long': 50, 'Peter,': 50, 'because': 49, 'made': 48, 'went': 48, 'last': 48, 'moment': 48, 'should': 47, 'them,': 47, 'may': 47, 'think': 47, 'me': 47, 'though': 46, 'Mr.': 46, 'through': 46, 'Then': 46, 'after': 44, 'really': 44, 'let': 44, 'am': 44, 'There': 43, 'where': 43, 'heard': 43, 'round': 43, 'cried,': 42, 'even': 42, 'her.': 41, 'without': 41, 'most': 41, 'before': 41, 'saw': 41, 'rather': 40, 'put': 40, 'once': 40, 'has': 40, 'every': 39, 'found': 38, '“It': 38, 'get': 38, 'tell': 38, 'Of': 37, 'her,': 37, 'night': 37, 'ever': 37, 'them.': 37, 'pirates': 37, 'two': 36, 'gave': 36, 'say': 36, '“What': 36, 'You': 35, 'almost': 35, 'looking': 35, 'look': 35, 'us': 35, 'upon': 35, '“You': 35, 'work': 35, 'Chapter': 34, 'sat': 34, 'Nana': 34, 'too': 34, 'looked': 33, 'mother': 33, 'got': 33, 'man': 33, 'thing': 33, 'If': 33, 'asked': 33, 'again': 33, 'In': 33, 'told': 33, 'hand': 32, 'hear': 32, 'going': 31, 'off': 31, 'each': 31, 'back': 31, 'This': 30, 'THE': 30, 'much': 30, 'called': 30, 'some': 30, 'take': 30, 'things': 29, 'sure': 29, 'now,': 29, 'fell': 29, 'might': 28, 'sound': 28, 'away': 28, 'Smee': 28, 'And': 27, 'its': 27, 'Peter.': 27, 'said.': 27, 'himself': 27, 'want': 27, '“And': 27, 'make': 27, 'Peter’s': 27, 'Tinker': 27, 'under': 27, 'electronic': 27, 'while': 26, 'soon': 26, 'For': 26, 'Wendy’s': 26, 'being': 26, 'light': 26, 'Tink': 26, 'face': 26, 'Slightly': 26, 'many': 25, 'good': 25, 'bed': 25, 'these': 25, 'shall': 25, 'eyes': 25, 'our': 25, 'give': 25, 'To': 25, 'home': 25, 'another': 24, '“Oh,': 24, 'can’t': 24, 'house': 24, 'took': 24, 'three': 24, 'As': 24, 'well': 24, 'you,': 24, 'replied': 24, 'Wendy.': 24, 'Tootles': 24, 'old': 23, 'seemed': 23, 'nursery': 23, 'something': 23, 'again,': 23, 'against': 23, 'great': 23, 'works': 23, 'again.': 22, 'sometimes': 22, 'stood': 22, 'felt': 22, 'till': 22, 'tried': 22, 'pirate': 22, 'copyright': 21, 'until': 21, 'John,': 21, 'same': 21, '“No,': 21, 'suddenly': 21, 'lost': 21, 'flew': 21, 'Hook’s': 21, 'except': 20, 'seen': 20, 'room': 20, 'part': 20, '“Yes,': 20, '“and': 20, 'boy': 20, 'window': 20, 'help': 20, 'save': 20, 'terms': 20, 'Gutenberg': 20, 'A': 19, 'own': 19, '“If': 19, 'me,': 19, 'What': 19, '“The': 19, 'others': 19, 'fly': 19, 'redskins': 19, 'up,': 18, 'whether': 18, 'cried.': 18, 'days': 18, 'also': 18, 'this,': 18, 'When': 18, 'island': 18, 'At': 18, 'full': 18, 'tree': 18, 'head': 18, 'out.': 18, 'new': 18, 'So': 18, 'use': 18, 'Now': 18, 'Hook,': 18, 'All': 17, 'ran': 17, 'used': 17, ' ...
# Counter({',': 3976, '.': 2789, 'the': 2324, '”': 1463, '“': 1462, 'and': 1421, 'to': 1242, 'a': 960, 'was': 932, 'of': 919, 'he': 879, 'in': 697, 'it': 662, 'that': 609, 'had': 501, 'you': 484, 'they': 476, 'she': 476, 'I': 465, 'her': 456, 'his': 456, 'not': 414, 'Peter': 400, 'but': 395, ';': 389, 'for': 381, 'is': 373, 'with': 359, 'said': 358, 'Wendy': 356, 'on': 352, 'him': 338, '?': 318, 'at': 317, 'as': 315, '’s': 280, 'them': 279, '-': 266, 'have': 258, 'be': 257, 'all': 248, 'were': 246, '!': 235, 'this': 225, 'so': 218, 'their': 213, 'would': 211, 'one': 202, 'are': 202, 'by': 186, 'He': 181, 'do': 180, 'It': 174, 'up': 165, 'The': 165, 'out': 164, 'n’t': 159, 'when': 155, 'no': 153, 'Hook': 153, 'we': 148, 'from': 146, 'could': 146, 'there': 144, 'cried': 136, 'who': 136, 'been': 136, 'or': 135, 'John': 133, 'if': 132, 'now': 129, 'did': 128, 'which': 126, 'She': 126, 'time': 124, 'Darling': 115, 'They': 112, 'about': 112, 'what': 112, 'Michael': 110, 'see': 103, 'an': 103, 'boys': 101, 'into': 101, 'me': 101, 'little': 99, 'children': 94, 'like': 94, 'know': 93, 'only': 90, 'mother': 89, 'again': 89, 'will': 88, 'other': 88, 'But': 88, 'night': 88, 'way': 87, 'then': 86, 'first': 83, 'Project': 82, 'Gutenberg': 82, 'your': 80, 'more': 79, 'thought': 78, 'go': 77, 'came': 76, 'just': 76, 'You': 75, ':': 74, 'Mrs.': 72, '—': 72, 'must': 71, 'any': 70, 'my': 70, 'knew': 69, 'course': 69, 'never': 67, 'can': 65, 'Then': 65, 'very': 64, 'Nana': 64, 'back': 63, 'how': 63, 'quite': 62, 'bed': 62, 'over': 62, 'What': 62, 'come': 61, 'down': 61, 'There': 61, 'such': 60, 'say': 60, 'once': 60, 'than': 60, 'moment': 59, 'last': 58, 'still': 58, 'think': 58, 'hand': 57, 'tm': 57, 'man': 56, 'And': 56, 'away': 56, 'No': 55, 'Tink': 55, 'Smee': 55, 'went': 54, 'pirates': 54, 'always': 53, 'before': 53, 'Slightly': 53, 'made': 52, 'long': 52, 'If': 52, 'us': 52, 'because': 51, 'Oh': 50, 'round': 50, 'should': 49, 'through': 49, 'work': 49, 'ever': 48, 'though': 48, 'am': 48, 'heard': 47, 'may': 47, 'let': 47, 'Mr.': 46, 'house': 46, 'really': 46, 'thing': 46, 'Yes': 46, 'asked': 46, 'after': 45, 'Of': 45, 'where': 45, 'tell': 45, 'Tootles': 45, 'saw': 44, 'himself': 44, 'off': 42, 'even': 42, 'too': 42, 'two': 41, 'rather': 41, 'without': 41, 'most': 41, 'has': 41, 'look': 41, '’': 40, 'put': 40, 'get': 40, 'boy': 40, 'window': 40, 'nursery': 39, 'light': 39, 'every': 39, 'looking': 39, 'eyes': 39, 'much': 38, 'room': 38, 'found': 38, 'make': 38, 'Nibs': 38, 'sound': 37, 'In': 37, 'told': 37, 'home': 37, 'gave': 36, 'father': 36, 'good': 36, 'things': 36, 'That': 36, 'sure': 36, 'right': 35, 'almost': 35, 'sat': 35, 'upon': 35, 'voice': 35, 'This': 34, 'Chapter': 34, 'looked': 34, 'Now': 34, 'called': 34, 'also': 34, 'We': 34, 'hear': 34, 'Do': 34, 'fly': 34, 'lady': 33, 'got': 33, 'going': 33, 'well': 33, 'island': 33, 'take': 33, 'water': 33, 'pirate': 33, 'another': 32, ')': 32, 'tree': 32, 'face': 32, 'works': 32, 'each': 31, '(': 31, 'To': 31, 'fell': 31, 'THE': 30, 'day': 30, 'here': 30, 'some': 30, 'replied': 30, 'ground': 30, 'soon': 29, 'mouth': 29, 'might': 29, 'lagoon': 29, 'want': 29, 'Tinker': 29, 'Bell': 29, 'Starkey': 29, 'ship': 29, 'A': 28, 'old': 28, 'For': 28, 'three': 28, 'cry': 28, 'believe': 28, 'best': 28, 'dear': 28, 'Jane': 28, '  ': 28, 'while': 27, 'ca': 27, 'many': 27, 'As': 27, 'these': 27, 'its': 27, 'others': 27, 'under': 27, 'electronic': 27, 'Pan': 26, 'why': 26, 'being': 26, 'shall': 26, 'our': 26, 'So': 26, 'give': 26, 'help': 26, 'air': 26, 'redskins': 26, 'seen': 25, 'tried': 25, 'crocodile': 25, 'took': 24, 'own': 24, 'same': 24, 'How': 24, 'asleep': 24, 'something': 24, 'trees': 24, 'great': 24, 'story': 24, 'flew': 24, 'Foundation': 24, 'door': 23, 'seemed': 23, 'floor': 23, 'felt': 23, 'against': 23, 'does': 23, 'lost': 23, 'captain': 23, 'bird': 23, 'copyright': 22, 'days': 22, 'sometimes': 22, 'Neverland': 22, 'part': 22, 'stood': 22, 'words': 22, 'remember': 22, 'till': 22, 'head': 22,  ...
# [(',', 3976), ('.', 2789), ('the', 2324), ('”', 1463), ('“', 1462), ('and', 1421), ('to', 1242), ('a', 960), ('was', 932), ('of', 919), ('he', 879), ('in', 697), ('it', 662), ('that', 609), ('had', 501), ('you', 484), ('they', 476), ('she', 476), ('I', 465), ('her', 456)]

# %% [markdown]
# b) You will see that punctuation marks are among the most frequent items in the result. Remove them from the counter.
#
# <details>
# <summary> Hints </summary>
# 	<ul>
# 		<li> <code>string.punctuation</code> contains a list of punctuation symbols (you’ll need to import string first)</li>
# 		<li>You can delete the 'and' item from the counter with <code>del c[‘and’]</code>.</li>
# 	</ul>
# </details>

# %%
words = [token.text for token in clean_doc if not token.is_punct]

counter_1 = Counter(words)


print(counter_1.most_common(20))
# Out:
# [('the', 2324), ('and', 1421), ('to', 1242), ('a', 960), ('was', 932), ('of', 919), ('he', 879), ('in', 697), ('it', 662), ('that', 609), ('had', 501), ('you', 484), ('they', 476), ('she', 476), ('I', 465), ('her', 456), ('his', 456), ('not', 414), ('Peter', 400), ('but', 395)]

# %% [markdown]
# c) It would be nice if we could display the frequency distribution as a nicely formatted table. Let us use a
# DataFrame from the Pandas package for this. In general, it is easy to populate a DataFrame with the
# contents of a Python dictionary, as in the following code snippet:
#
# ```python
# import pandas as pd
#
# d = {‘apple’: 5, ‘orange’: 8, ‘banana’: 51, ‘strawberry’: 20}
# df = pd.DataFrame(d.items(), columns=['fruit', 'number'])
#
# df.head()    # Display the first rows
# ```
#
# You can do the same with your word counter.
#
# How many types and how many tokens does the text contain? What is its type-token-ratio?

# %%
import pandas as pd

df = pd.DataFrame(counter_1.items(),columns=['words','count'])


df.head()
number_of_types = len(counter_1)
number_of_tokens = sum(counter_1.values())

type_token_ratio = number_of_types / number_of_tokens

print("Number of types:", number_of_types)
print("Number of tokens:", number_of_tokens)
print("Type-token ratio:", type_token_ratio)
# Out:
# Number of types: 5746
# Number of tokens: 51096
# Type-token ratio: 0.11245498669171755

# %% [markdown]
# d) With Pandas, you can easily select rows of a dataframe according to a particular criterion. For example,
# this command displays all words that occur ten times or more:
#
# ```python
# df[df[‘count’] >= 10]
# ```
#
# How many hapaxes are in the dataset? What percentage of all word types are hapaxes?
# How many word types start with upper case A?

# %%
hapaxes = df[df['count']==1]

print("Number of hapaxes",len(hapaxes))

percentage = len(hapaxes)/len(df)*100

print("Percentage of hapaxes",percentage)


A_words = df[df['words'].str.startswith('A')]

print("Number of word types starting with A:", len(A_words))
# Out:
# Number of hapaxes 2852
# Percentage of hapaxes 49.634528367560044
# Number of word types starting with A: 49

# %% [markdown]
# ## Part 3: Plotting with Matplotlib
#
# Matplotlib is a package for making plots and figures in Python. When using Jupyter notebooks, the plots
# are directly displayed in the notebook. This code snippet generates a simple plot:
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# numbers = np.arange(10)
# print(numbers)
# plt.plot(numbers)
# ```

# %% [markdown]
# a) Let us create a plot from our frequency distribution. You can directly use the `plot()` method of the
# dataframe as follows:
#
# ```python
# df = df.sort_values('count', ascending=False)
# df.plot(x='word', y='count')
# ```
#
# Does the result of this plot correspond to your expectations?

# %%
df = df.sort_values('count',ascending=False)
df.plot(x='words',y='count')
# Out:
# <Axes: xlabel='words'>

# %% [markdown]
# b) Let's make some more visualizations.
#
# * Modify the command to only display the 20 most frequent words.
# * Try to display all words on the x-axis.
# * For frequency plots, it is more natural to use bar charts. Switch the type of the plot with the `kind='bar'` parameter.

# %%
df = df.sort_values('count',ascending=False)

df.head(20)

df.head(20).plot(x='words',y='count')
# Out:
# <Axes: xlabel='words'>

# %% [markdown]
# c) Zipf’s law states that the product of the frequency of a word and of its rank is approximately constant.
# Let us verify this law on a subset of our frequency distribution. Select the 2000 first words of the
# sorted frequency table. Reset the indices in the resulting dataframe so that we can use each index for the rank. Now, add a new column with the product of rank and frequency.
#
# <details>
# <summary>Hints</summary>
#
# ```python
# 	df_zipf = df[:2000].reset_index(drop=True)
# 	df_zipf['z'] = df_zipf.index.values * df_zipf['Count']
# ```
# </details>
#
# What are the highest, lowest and average values of z that you observe? Plot the z values as a line chart.

# %%
import matplotlib.pyplot as plt
df = df.sort_values('count', ascending=False)

df.plot(x='words', y='count')

plt.show()

top20 = df.head(20)

top20.plot(x='words',y='count',kind='bar')

plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
